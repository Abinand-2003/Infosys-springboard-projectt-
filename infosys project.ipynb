# %%
import os
import google.generativeai as genai

os.environ["GEMINI_API_KEY"] = "AIzaSyAchQOPGz5u6D7PWh5wuNFa9VyfL6xx8Zw" 
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

generation_config = {
    "temperature": 1.05,
    "top_p": 0.95,
    "top_k": 40,
    "max_output_tokens": 8192,  # Adjust if needed
    "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
    model_name="gemini-1.5-flash-8b",
    generation_config=generation_config,
)

def get_hospitality_recommendations(customer_profile):
    chat_session = model.start_chat(history=[])
    
    input_message = (
       "You are an expert in personalizing hotel guest experiences. Based on the "
        "following customer profile, recommend one or two amenities (e.g., spa, bar, pool) "
        "and one dining style that aligns with their preferences:\n\n"
        f"{customer_profile}"
    )
    
    response = chat_session.send_message(input_message)
    return response.text

if __name__ == "__main__":
    customer_profile = """
    - Age: 40
    - Traveling for leisure
    - Prefers luxury experiences
    - Non-vegetarian
    - Enjoys spa and wellness activities
    - Interested in nightlife and fine dining
    - Traveling as a couple
    """
    
    # Get recommendations
    recommendations = get_hospitality_recommendations(customer_profile)
    print("Recommendations:")
    print(recommendations)
# Out:
# Recommendations:
# For this discerning couple, I recommend focusing on a **sophisticated and luxurious experience** that blends relaxation, culinary indulgence, and vibrant nightlife.
#
# **Amenity Recommendation 1:  Upscale Spa & Wellness Center**
#
# A spa with a strong emphasis on personalized treatments, perhaps featuring a dedicated couple's suite or a private hydrotherapy experience, would be highly appealing.  This goes beyond a basic spa; it needs to offer premium services like aromatherapy, specialized massages (couples massages, perhaps), and high-end skincare products.  Consider a spa that integrates elements of mindfulness, like meditation rooms or yoga studios.
#
# **Amenity Recommendation 2 (Secondary):  A Chic Rooftop Bar/Lounge**
#
# A sophisticated rooftop bar with panoramic views, offering curated cocktails, premium wines, and an elegant ambiance, is an excellent addition.  Live music (jazz or acoustic) would elevate the experience further. This provides an ideal space for pre-dinner drinks and a sophisticated nightlife option.
#
# **Dining Recommendation:  Fine-Dining Restaurant with Tasting Menus**
#
# A fine-dining restaurant known for its sophisticated tasting menus and expertly crafted, non-vegetarian dishes is a must. The restaurant should possess a stunning interior design, impeccable service, and a wine list that complements the menu.  A focus on locally-sourced ingredients would be a bonus.
#
# **Why this combination works:**
#
# * **Luxury:** The spa, rooftop bar, and fine dining restaurant all cater to a desire for luxury and exclusivity.
# * **Relaxation and Wellness:** The spa directly addresses the guest's interest in spa and wellness activities.
# * **Nightlife and Culture:** The rooftop bar offers a sophisticated nightlife option, and the fine dining experience provides an element of cultural immersion.
# * **Non-Vegetarian Preference:**  The fine-dining restaurant caters directly to this requirement.
# * **Couple's Trip:**  The spa experience and shared dining can be tailored to creating intimate moments for the couple.
#
#
# This approach provides a holistic experience, blending relaxation with excitement and allowing the couple to indulge in their shared interests in a luxurious and memorable way.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('final_data.csv')
df.head()
# Out:
#                             hotel_name                   review_summary  \
# 0  Hotel Hilton London Gatwick Airport                         Awful...
# 1              Hilton London Metropole                        Terrible
# 2                 Hilton London Euston   Double deposit taken from bank
# 3              Hilton London Metropole              Super disappointed!
# 4              Hilton London Metropole  Dissatisfied Hilton gold number
#
#                                               review  score  \
# 0  Its hard to find words that can describe this ...      1
# 1  Absolutely terrible. Cracked ceiling, tiny roo...      1
# 2  Very disappointed firstly i checked in online ...      1
# 3  First of all we arrived wanting to park at the...      1
# 4  Hello,  I currently staying @ Hilton Metropole...      1
#
#                                          preferences   customer_name  \
# 0  Spa services, Fitness center, Romantic dining ...     Emma Martin
# 1  Spa services, Fitness center, Romantic dining ...  Giulia Bianchi
# 2  Wellness programs, Community events, Quiet stu...     Priya Verma
# 3  Community events, Fitness center, Quiet study ...       Wei Zhang
# 4  Wellness programs, Community events, Quiet stu...     Marie Petit
#
#   customer_profile
# 0           Couple
# 1           Couple
# 2             Solo
# 3             Solo
# 4             Solo
